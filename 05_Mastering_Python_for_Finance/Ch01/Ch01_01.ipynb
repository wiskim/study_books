# %%
import quandl

# %%
QUANDL_API_KEY = '1yYHfzzuFshPzyQMsksg'
quandl.ApiConfig.api_key = QUANDL_API_KEY
df = quandl.get('EURONEXT/ABN')

# %%
df.head()
# Out:
#              Open   High     Low   Last      Volume      Turnover
# Date
# 2015-11-20  18.18  18.43  18.000  18.35  38392898.0  7.003281e+08
# 2015-11-23  18.45  18.70  18.215  18.61   3352514.0  6.186446e+07
# 2015-11-24  18.70  18.80  18.370  18.80   4871901.0  8.994087e+07
# 2015-11-25  18.85  19.50  18.770  19.45   4802607.0  9.153862e+07
# 2015-11-26  19.48  19.67  19.410  19.43   1648481.0  3.220713e+07

# %%
df.tail()
# Out:
#              Open   High    Low   Last      Volume    Turnover
# Date
# 2020-06-08  9.014  9.562  8.852  9.066  10791421.0  99796267.0
# 2020-06-09  9.196  9.264  8.462  8.566   9089213.0  79051249.0
# 2020-06-10  8.722  8.960  8.234  8.316   7318341.0  61984138.0
# 2020-06-11  7.880  8.002  7.540  7.584   8138546.0  63080720.0
# 2020-06-12  7.432  7.920  7.340  7.644   8416957.0  65138525.0

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

df.plot();

# %%
prices = df['Last']
volumes = df['Volume']

# %%
prices.head()
# Out:
# Date
# 2015-11-20    18.35
# 2015-11-23    18.61
# 2015-11-24    18.80
# 2015-11-25    19.45
# 2015-11-26    19.43
# Name: Last, dtype: float64

# %%
volumes.tail()
# Out:
# Date
# 2020-06-08    10791421.0
# 2020-06-09     9089213.0
# 2020-06-10     7318341.0
# 2020-06-11     8138546.0
# 2020-06-12     8416957.0
# Name: Volume, dtype: float64

# %%
top = plt.subplot2grid((4, 4), (0, 0), rowspan=3, colspan=4)
top.plot(prices.index, prices, label='Last')
plt.title('ABN Last Price from 2015-2020')
plt.legend(loc=2)

bottom = plt.subplot2grid((4, 4), (3, 0), rowspan=1, colspan=4)
bottom.bar(volumes.index, volumes)
plt.title('ABN Daily Trading Volume')

plt.gcf().set_size_inches(12, 8)
plt.subplots_adjust(hspace=0.75)
