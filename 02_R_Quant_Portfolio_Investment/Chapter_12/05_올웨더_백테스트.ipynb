# %% [markdown]
# # 순정 올웨더 포트폴리오 백테스트

# %%
import pandas as pd
import pyfolio as pf

# %%
df = pd.read_csv('./files/allWeather_original.csv', index_col=0)
df.index = pd.to_datetime(df.index)
pf.create_returns_tear_sheet(df['portfolio.returns'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2008-07-02</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-22</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>144</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>6.854%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>122.191%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>8.011%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.47</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.93</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-14.69%</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# # 리스크 패리티 올웨더 포트폴리오 백테스트

# %%
df = pd.read_csv('./files/allWeather_riskparity.csv', index_col=0)
df.index = pd.to_datetime(df.index)
pf.create_returns_tear_sheet(df['portfolio.returns'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2009-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-22</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>132</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>5.599%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>82.549%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>6.249%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-12.742%</td>
#     </tr>
#     <tr>
# ...
