# %% [markdown]
# # 순정 올웨더 포트폴리오 백테스트

# %%
import pandas as pd
import pyfolio as pf
# Out:
# C:\Users\ksfc\Anaconda3\envs\py36_32bit\lib\site-packages\pyfolio\pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %%
df = pd.read_csv('./files/allWeather_original.csv', index_col=0)
df.index = pd.to_datetime(df.index)
pf.create_returns_tear_sheet(df['portfolio.returns'])

# %% [markdown]
# # 리스크 패리티 올웨더 포트폴리오 백테스트

# %%
df = pd.read_csv('./files/allWeather_riskparity.csv', index_col=0)
df.index = pd.to_datetime(df.index)
pf.create_returns_tear_sheet(df['portfolio.returns'])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2009-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-07-22</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>132</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>5.599%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>82.549%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>6.249%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.90</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.44</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.79</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-12.742%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.17</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.63</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.78</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.765%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>12.74</td>
#       <td>2020-02-21</td>
#       <td>2020-03-18</td>
#       <td>2020-07-06</td>
#       <td>97</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>11.42</td>
#       <td>2014-06-30</td>
#       <td>2016-01-19</td>
#       <td>2016-06-30</td>
#       <td>524</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.76</td>
#       <td>2012-10-01</td>
#       <td>2013-07-05</td>
#       <td>2014-05-28</td>
#       <td>433</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>7.03</td>
#       <td>2016-08-18</td>
#       <td>2016-12-15</td>
#       <td>2017-08-23</td>
#       <td>265</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>6.16</td>
#       <td>2018-01-26</td>
#       <td>2018-11-23</td>
#       <td>2019-03-22</td>
#       <td>301</td>
#     </tr>
#   </tbody>
# </table>
